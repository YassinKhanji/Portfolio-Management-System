# %%
from pprint import pprint
from os import getenv
from snaptrade_client import SnapTrade

snaptrade = SnapTrade(
    client_id=getenv(""),
    consumer_key=getenv("")
)

response = snaptrade.authentication.register_snap_trade_user(
    user_id="snaptrade-user-123"
)
pprint(response.body)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[1], line 10
#       3 from snaptrade_client import SnapTrade
#       5 snaptrade = SnapTrade(
#       6     client_id=getenv(""),
#       7     consumer_key="CONSUMER_KEY"
#       8 )
# ---> 10 response = snaptrade.authentication.register_snap_trade_user(
#      11     user_id="snaptrade-user-123"
#      12 )
#      13 pprint(response.body)
#
# File c:\Users\yassi\OneDrive\Documents\Business and Finance\Businesses\Portfolio Management\Backend\.venv\Lib\site-packages\snaptrade_client\paths\snap_trade_register_user\post.py:408, in RegisterSnapTradeUser.register_snap_trade_user(self, body, user_id)
#     403 """ Registers a new SnapTrade user under your Client ID. A user secret will be automatically generated for you and must be properly stored in your system. Most SnapTrade operations require a user ID and user secret to be passed in as parameters.  """
#     404 args = self._register_snap_trade_user_mapped_args(
#     405     body=body,
#     406     user_id=user_id,
#     407 )
# --> 408 return self._register_snap_trade_user_oapg(
#     409     body=args.body,
#     410 )
#
# File c:\Users\yassi\OneDrive\Documents\Business and Finance\Businesses\Portfolio Management\Backend\.venv\Lib\site-packages\snaptrade_client\paths\snap_trade_register_user\post.py:368, in BaseApi._register_snap_trade_user_oapg(self, body, skip_deserialization, timeout, accept_content_types, content_type, stream)
#     359     api_response = api_client.ApiResponseWithoutDeserialization(
#     360         body=json.loads(response.http_response.data) if is_json else response.http_response.data,
#     361         response=response.http_response,
#    (...)    364         headers=response.http_response.headers,
#     365     )
#     367 if not 200 <= api_response.status <= 299:
# --> 368     raise exceptions.ApiException(api_response=api_response)
#     370 return api_response
#
# ApiException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Sun, 28 Dec 2025 03:44:49 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'Server': 'gunicorn', 'Allow': 'POST, OPTIONS', 'X-Frame-Options': 'DENY', 'X-Request-ID': '3d7a969911c7c25d8e9c3e1c846bc9e6', 'X-RateLimit-Limit': '250', 'X-RateLimit-Remaining': '250', 'Vary': 'origin', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'same-origin', 'Cross-Origin-Opener-Policy': 'same-origin'})
# HTTP response body: {'detail': 'Please provide clientId in query params', 'status_code': 401, 'code': '1083'}
